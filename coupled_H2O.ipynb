# %% [markdown]
# # Reading the ROOT files

# %%
# exec(open("./do_imports.py").read())

import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
from sklearn.metrics import confusion_matrix, roc_auc_score, roc_curve, precision_recall_fscore_support
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn import metrics
from sklearn.tree import DecisionTreeClassifier

# %%
from torch_geometric.utils import from_networkx, add_self_loops
from torch_geometric.data import Data, Dataset, DataLoader
from torch_geometric.nn import GCNConv, ASAPooling, TopKPooling
from torch.nn import Linear, Sequential, ReLU, Dropout, Sigmoid
import torch
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F
import networkx as nx

# %%
from evaluate_results import *
# from batched_data import *
# import cnn_batched_data
from tqdm import tqdm
all_rates =load_obj('all_rates', directory='./')

# %%
from data.data_preprocessing import *

# %%
import pandas as pd

# %%
from GCN_utils import *

# %% [markdown]
# ### Prep data for model input

# %%
tgkw = dict(medium='h2o', max_dist=600.0, min_dist=0.,)
torch_graph = get_graph(**tgkw # max is 1584 cm 
)
# Out:
# ***Creating Graph...***
# ***Graph Created...***

# %%
val = GCNSeq('test_water_2sig', torch_graph, shuffle=False, batch_size=12)
train = GCNSeq('train_water_2sig', torch_graph, shuffle=False, batch_size=12)

# %% [markdown]
# ## Get sets of data for only dineutron cases

# %%
class GCNNet(torch.nn.Module):
    def __init__(self, final_out=3, n_pmts=2330):
        super(GCNNet, self).__init__()
        self.lin = Sequential(Linear(n_pmts*final_out, 32),
                              nn.BatchNorm1d(32),
                              ReLU(), 
                              Linear(32, 1),
                             )
        self.conv1 = GCNConv(5, 32)
        self.conv2 = GCNConv(32, 16)
        self.conv3 = GCNConv(16, final_out)
        self.final_out=final_out
    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x, edge_index,)
        x = F.relu(x)
        x = self.conv2(x, edge_index,)
        x = F.relu(x)
        x = self.conv3(x, edge_index,)
        x = F.relu(x)
        x = x.view(-1, self.final_out*n_pmts)
        x = self.lin(x)
        return x
        return x

# %%
torch.cuda.set_device(1)
device = torch.device("cuda")

# %%
tgkw = dict(medium='h2o', max_dist=600.0, min_dist=0.,)
torch_graph = get_graph(**tgkw # max is 1584 cm 
)
n_pmts = len(torch_graph.pos)
model = GCNNet(n_pmts=n_pmts).to(device)
# Out:
# ***Creating Graph...***
# ***Graph Created...***

# %%
statedict = torch.load('GCN_models/model_water_last.pkl')

# %%
model.load_state_dict(statedict)
model.eval()
# Out:
# GCNNet(
#   (lin): Sequential(
#     (0): Linear(in_features=6990, out_features=32, bias=True)
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Linear(in_features=32, out_features=1, bias=True)
#   )
#   (conv1): GCNConv(5, 32)
#   (conv2): GCNConv(32, 16)
#   (conv3): GCNConv(16, 3)
# )

# %%
def get_gcn_predictions(model, datagen, device='cpu'):
    model.eval()
    correct = 0.0
    loss = 0.0
    totsize = len(datagen.y)
    net_out = torch.zeros((len(datagen.y),1))
    batch_size=datagen.batch_size
    with tqdm(datagen, unit="batch") as tepoch:
        tepoch.set_description(f'Validating..')
        for i, data in enumerate(tepoch):
            inputs = data.to(device)
            outputs = torch.sigmoid(model(inputs).detach())
            net_out[i*batch_size:(i+1)*batch_size] = outputs
    del inputs, outputs
    return net_out

# %% [markdown]
# ### Prep data for model input

# %% [markdown]
# ## Create function to return only true 2-signal data

# %%
gcn_out_test = get_gcn_predictions(model, val, device=device)
gcn_out_train =  get_gcn_predictions(model, train, device=device)
# Out:
# Validating..: 100%|██████████| 216/216 [00:17<00:00, 12.49batch/s]
# Validating..: 100%|██████████| 646/646 [00:57<00:00, 11.16batch/s]

# %%
gcn_scores = np.asarray(gcn_out_test[:,0])

# %%
kw = dict(histtype='step', bins=50, range=[0,1])
kw = dict(histtype='step', bins=50, range=[0,1])
plt.hist(gcn_scores[val.y==0], **kw, label='first event from fast-n')
plt.hist(gcn_scores[val.y==1], **kw, label='IBD positron')
plt.xlabel('GCN Output Probability', fontsize=14)
plt.ylabel('Counts', fontsize=12)
# plt.yscale('log')
plt.legend()
plt.show()

# %%
ml = ML_Evaluation(val.y, gcn_out_test)
ml.draw_confmat(extra_title='\nH$_2$O: GCN')
gcn_tpr, gcn_fpr, gcn_thresholds = ml.draw_roc(extra_title='\nH$_2$O: GCN')

gcn_acceptances = dict(fpr=gcn_fpr, tpr=gcn_tpr)
quick_analysis(gcn_acceptances, medium='h2o')

results['gcn'] = dict(scores=gcn_scores, tpr=gcn_tpr, fpr=gcn_fpr, thresholds=gcn_thresholds)

# %% [markdown]
# ------

# %% [markdown]
# ## FRED Random Forest

# %%
dimensions = [
    'n9', 'n100', 'n400',
    'x', 'y', 'z', # 'r',
    'id_plus_dr_hit', 
    'good_dir', 
    'good_dir_next', # 'good_pos_next', 
    'good_pos',
    'closestPMT', 'closestPMT_next', # 'distpmt', 
    'drNextr', # 'dzNextz', 
     'dt_next_us', 
    'azimuth_ks',  'azimuth_ks_next',
    'n100_next','n9_next',
    'pe', 
#     'beta_four',
    'beta_one', 'beta_two', 'beta_three', 'beta_four', 'beta_five', 'beta_six',
]

# %%
X_train3, y_train, X_test3, y_test, sc = scale_features(train, val, dimensions)
# Out:
# Remaining variables selected for analysis: 25
# Remaining variables selected for analysis: 25

# %%
new_train, new_test, yy_train, yy_test, dims_add = add_netoutput_to_rf(X_train3, X_test3, y_train, y_test, 
                                                            nn_out_train=None, nn_out_test=None, fred_dimensions=dimensions )

# %%
n_trees = np.array([20, 50, 100, 200])
max_depth = np.array([6, 8, 10, 12, 15])
min_per_leaf = np.array([2, 10, 50, 100])

# %%
train_acc_rf = np.zeros((len(n_trees), len(max_depth), len(min_per_leaf)))
test_acc_rf = np.zeros((len(n_trees), len(max_depth), len(min_per_leaf)))

# %%
for i, ntrees in enumerate(n_trees):
    for j, depthmax in enumerate(max_depth):
        for k, minsperleaf in enumerate(min_per_leaf):
            if train_acc_rf[i,j,k]>0:
                continue
            print(f'Calculating: n_bc={ntrees} max_depth:{depthmax} min_samples_per_leaf:{minsperleaf}')
            #Create a Gaussian Classifier
            rf=RandomForestClassifier(
                n_estimators=ntrees, 
                max_depth=depthmax, 
                min_samples_leaf=minsperleaf,
                bootstrap=True,
            )
            #Train the model using the training sets
            rf.fit(new_train,yy_train)
            train_acc_rf[i,j,k] = rf.score(new_train, y_train)
            test_acc_rf[i,j,k] = rf.score(new_test, y_test)
            print("Train Acc: %.4f"%(train_acc_rf[i,j,k]))
            print("Val.  Acc: %.4f"%(test_acc_rf[i,j,k]))
# Out:
# Calculating: n_bc=20 max_depth:6 min_samples_per_leaf:2
# Train Acc: 0.9022
# Val.  Acc: 0.8818
# Calculating: n_bc=20 max_depth:6 min_samples_per_leaf:10
# Train Acc: 0.8954
# Val.  Acc: 0.8803
# Calculating: n_bc=20 max_depth:6 min_samples_per_leaf:50
# Train Acc: 0.8853
# Val.  Acc: 0.8749
# Calculating: n_bc=20 max_depth:6 min_samples_per_leaf:100
# Train Acc: 0.8802
# Val.  Acc: 0.8768
# Calculating: n_bc=20 max_depth:8 min_samples_per_leaf:2
# Train Acc: 0.9258
# Val.  Acc: 0.8861
# Calculating: n_bc=20 max_depth:8 min_samples_per_leaf:10
# Train Acc: 0.9150
# Val.  Acc: 0.8931
# Calculating: n_bc=20 max_depth:8 min_samples_per_leaf:50
# Train Acc: 0.8919
# Val.  Acc: 0.8834
# Calculating: n_bc=20 max_depth:8 min_samples_per_leaf:100
# Train Acc: 0.8841
# Val.  Acc: 0.8783
# Calculating: n_bc=20 max_depth:10 min_samples_per_leaf:2
# Train Acc: 0.9499
# Val.  Acc: 0.8946
# Calculating: n_bc=20 max_depth:10 min_samples_per_leaf:10
# Train Acc: 0.9247
# Val.  Acc: 0.8911
# Calculating: n_bc=20 max_depth:10 min_samples_per_leaf:50
# Train Acc: 0.8977
# Val.  Acc: 0.8834
# Calculating: n_bc=20 max_depth:10 min_samples_per_leaf:100
# Train Acc: 0.8831
# Val.  Acc: 0.8807
# Calculating: n_bc=20 max_depth:12 min_samples_per_leaf:2
# Train Acc: 0.9702
# Val.  Acc: 0.8938
# Calculating: n_bc=20 max_depth:12 min_samples_per_leaf:10
# Train Acc: 0.9295
# Val.  Acc: 0.8950
# Calculating: n_bc=20 max_depth:12 min_samples_per_leaf:50
# Train Acc: 0.8943
# Val.  Acc: 0.8857
# Calculating: n_bc=20 max_depth:12 min_samples_per_leaf:100
# Train Acc: 0.8837
# Val.  Acc: 0.8811
# Calculating: n_bc=20 max_depth:15 min_samples_per_leaf:2
# Train Acc: 0.9809
# Val.  Acc: 0.8973
# Calculating: n_bc=20 max_depth:15 min_samples_per_leaf:10
# Train Acc: 0.9304
# Val.  Acc: 0.8876
# Calculating: n_bc=20 max_depth:15 min_samples_per_leaf:50
# Train Acc: 0.8941
# Val.  Acc: 0.8876
# Calculating: n_bc=20 max_depth:15 min_samples_per_leaf:100
# Train Acc: 0.8839
# Val.  Acc: 0.8752
# Calculating: n_bc=50 max_depth:6 min_samples_per_leaf:2
# Train Acc: 0.8990
# Val.  Acc: 0.8830
# Calculating: n_bc=50 max_depth:6 min_samples_per_leaf:10
# Train Acc: 0.8982
# Val.  Acc: 0.8830
# Calculating: n_bc=50 max_depth:6 min_samples_per_leaf:50
# Train Acc: 0.8880
# Val.  Acc: 0.8807
# Calculating: n_bc=50 max_depth:6 min_samples_per_leaf:100
# Train Acc: 0.8806
# Val.  Acc: 0.8768
# Calculating: n_bc=50 max_depth:8 min_samples_per_leaf:2
# Train Acc: 0.9268
# Val.  Acc: 0.8911
# Calculating: n_bc=50 max_depth:8 min_samples_per_leaf:10
# Train Acc: 0.9159
# Val.  Acc: 0.8946
# Calculating: n_bc=50 max_depth:8 min_samples_per_leaf:50
# Train Acc: 0.8948
# Val.  Acc: 0.8845
# Calculating: n_bc=50 max_depth:8 min_samples_per_leaf:100
# Train Acc: 0.8824
# Val.  Acc: 0.8745
# Calculating: n_bc=50 max_depth:10 min_samples_per_leaf:2
# Train Acc: 0.9527
# Val.  Acc: 0.8938
# Calculating: n_bc=50 max_depth:10 min_samples_per_leaf:10
# Train Acc: 0.9269
# Val.  Acc: 0.8946
# Calculating: n_bc=50 max_depth:10 min_samples_per_leaf:50
# Train Acc: 0.8967
# Val.  Acc: 0.8900
# Calculating: n_bc=50 max_depth:10 min_samples_per_leaf:100
# Train Acc: 0.8827
# Val.  Acc: 0.8733
# Calculating: n_bc=50 max_depth:12 min_samples_per_leaf:2
# Train Acc: 0.9693
# Val.  Acc: 0.8950
# Calculating: n_bc=50 max_depth:12 min_samples_per_leaf:10
# Train Acc: 0.9304
# Val.  Acc: 0.8981
# Calculating: n_bc=50 max_depth:12 min_samples_per_leaf:50
# Train Acc: 0.8963
# Val.  Acc: 0.8884
# Calculating: n_bc=50 max_depth:12 min_samples_per_leaf:100
# Train Acc: 0.8831
# Val.  Acc: 0.8764
# Calculating: n_bc=50 max_depth:15 min_samples_per_leaf:2
# Train Acc: 0.9848
# Val.  Acc: 0.8919
# Calculating: n_bc=50 max_depth:15 min_samples_per_leaf:10
# Train Acc: 0.9331
# Val.  Acc: 0.8969
# Calculating: n_bc=50 max_depth:15 min_samples_per_leaf:50
# Train Acc: 0.8952
# Val.  Acc: 0.8826
# Calculating: n_bc=50 max_depth:15 min_samples_per_leaf:100
# Train Acc: 0.8832
# Val.  Acc: 0.8783
# Calculating: n_bc=100 max_depth:6 min_samples_per_leaf:2
# Train Acc: 0.9009
# Val.  Acc: 0.8861
# Calculating: n_bc=100 max_depth:6 min_samples_per_leaf:10
# Train Acc: 0.8960
# Val.  Acc: 0.8807
# Calculating: n_bc=100 max_depth:6 min_samples_per_leaf:50
# Train Acc: 0.8890
# Val.  Acc: 0.8787
# Calculating: n_bc=100 max_depth:6 min_samples_per_leaf:100
# Train Acc: 0.8839
# Val.  Acc: 0.8752
# Calculating: n_bc=100 max_depth:8 min_samples_per_leaf:2
# Train Acc: 0.9280
# Val.  Acc: 0.8919
# Calculating: n_bc=100 max_depth:8 min_samples_per_leaf:10
# Train Acc: 0.9180
# Val.  Acc: 0.8904
# Calculating: n_bc=100 max_depth:8 min_samples_per_leaf:50
# Train Acc: 0.8970
# Val.  Acc: 0.8857
# Calculating: n_bc=100 max_depth:8 min_samples_per_leaf:100
# Train Acc: 0.8839
# Val.  Acc: 0.8783
# Calculating: n_bc=100 max_depth:10 min_samples_per_leaf:2
# Train Acc: 0.9519
# Val.  Acc: 0.8919
# Calculating: n_bc=100 max_depth:10 min_samples_per_leaf:10
# Train Acc: 0.9261
# Val.  Acc: 0.8938
# Calculating: n_bc=100 max_depth:10 min_samples_per_leaf:50
# Train Acc: 0.8959
# Val.  Acc: 0.8838
# Calculating: n_bc=100 max_depth:10 min_samples_per_leaf:100
# Train Acc: 0.8857
# Val.  Acc: 0.8814
# Calculating: n_bc=100 max_depth:12 min_samples_per_leaf:2
# Train Acc: 0.9715
# Val.  Acc: 0.8954
# Calculating: n_bc=100 max_depth:12 min_samples_per_leaf:10
# Train Acc: 0.9305
# Val.  Acc: 0.8935
# Calculating: n_bc=100 max_depth:12 min_samples_per_leaf:50
# Train Acc: 0.8954
# Val.  Acc: 0.8873
# Calculating: n_bc=100 max_depth:12 min_samples_per_leaf:100
# Train Acc: 0.8879
# Val.  Acc: 0.8811
# Calculating: n_bc=100 max_depth:15 min_samples_per_leaf:2
# Train Acc: 0.9853
# Val.  Acc: 0.8950
# Calculating: n_bc=100 max_depth:15 min_samples_per_leaf:10
# Train Acc: 0.9319
# Val.  Acc: 0.8942
# Calculating: n_bc=100 max_depth:15 min_samples_per_leaf:50
# Train Acc: 0.8963
# Val.  Acc: 0.8861
# Calculating: n_bc=100 max_depth:15 min_samples_per_leaf:100
# Train Acc: 0.8870
# Val.  Acc: 0.8768
# Calculating: n_bc=200 max_depth:6 min_samples_per_leaf:2
# Train Acc: 0.8992
# Val.  Acc: 0.8876
# Calculating: n_bc=200 max_depth:6 min_samples_per_leaf:10
# Train Acc: 0.8969
# Val.  Acc: 0.8830
# Calculating: n_bc=200 max_depth:6 min_samples_per_leaf:50
# Train Acc: 0.8911
# Val.  Acc: 0.8822
# Calculating: n_bc=200 max_depth:6 min_samples_per_leaf:100
# Train Acc: 0.8806
# Val.  Acc: 0.8772
# Calculating: n_bc=200 max_depth:8 min_samples_per_leaf:2
# Train Acc: 0.9280
# Val.  Acc: 0.8958
# Calculating: n_bc=200 max_depth:8 min_samples_per_leaf:10
# Train Acc: 0.9167
# Val.  Acc: 0.8931
# Calculating: n_bc=200 max_depth:8 min_samples_per_leaf:50
# Train Acc: 0.8957
# Val.  Acc: 0.8845
# Calculating: n_bc=200 max_depth:8 min_samples_per_leaf:100
# Train Acc: 0.8870
# Val.  Acc: 0.8783
# Calculating: n_bc=200 max_depth:10 min_samples_per_leaf:2
# Train Acc: 0.9543
# Val.  Acc: 0.8938
# Calculating: n_bc=200 max_depth:10 min_samples_per_leaf:10
# Train Acc: 0.9283
# Val.  Acc: 0.8958
# Calculating: n_bc=200 max_depth:10 min_samples_per_leaf:50
# Train Acc: 0.8965
# Val.  Acc: 0.8884
# Calculating: n_bc=200 max_depth:10 min_samples_per_leaf:100
# Train Acc: 0.8844
# Val.  Acc: 0.8756
# Calculating: n_bc=200 max_depth:12 min_samples_per_leaf:2
# Train Acc: 0.9713
# Val.  Acc: 0.8989
# Calculating: n_bc=200 max_depth:12 min_samples_per_leaf:10
# Train Acc: 0.9301
# Val.  Acc: 0.8927
# Calculating: n_bc=200 max_depth:12 min_samples_per_leaf:50
# Train Acc: 0.8978
# Val.  Acc: 0.8880
# Calculating: n_bc=200 max_depth:12 min_samples_per_leaf:100
# Train Acc: 0.8862
# Val.  Acc: 0.8776
# Calculating: n_bc=200 max_depth:15 min_samples_per_leaf:2
# Train Acc: 0.9859
# Val.  Acc: 0.8985
# Calculating: n_bc=200 max_depth:15 min_samples_per_leaf:10
# Train Acc: 0.9335
# Val.  Acc: 0.8938
# Calculating: n_bc=200 max_depth:15 min_samples_per_leaf:50
# Train Acc: 0.8978
# Val.  Acc: 0.8861
# Calculating: n_bc=200 max_depth:15 min_samples_per_leaf:100
# Train Acc: 0.8853
# Val.  Acc: 0.8803

# %%
# print n trees vs. n_boost vs. accuracy 
plt.figure()
for i, depthmax in enumerate(max_depth):
    plt.plot(n_trees, train_acc_rf[:,i,1], label=depthmax)
    plt.plot(n_trees, test_acc_rf[:,i,1], label=depthmax, linestyle='--')
plt.xscale('log')
plt.legend(ncol=2)
plt.show()

# %%
# best_score = np.max(test_acc_rf)
# best_params = np.argwhere(test_acc_rf==best_score)[0]
# ntrees = n_trees[best_params[0]]
# depthmax = max_depth[best_params[1]]
# minperleaf = min_per_leaf[best_params[2]]
print(f'Best Test Score:{best_score} n_trees={ntrees} depthmax={depthmax} minperleaf={minperleaf}')
rf=RandomForestClassifier(n_estimators=ntrees, 
    max_depth=depthmax, 
    bootstrap=True, min_samples_leaf=minperleaf,
)
rf.fit(new_train,yy_train)
# Out:
# Best Test Score:0.899 n_trees=200 depthmax=12 minperleaf=2
# RandomForestClassifier(max_depth=12, min_samples_leaf=2, n_estimators=200)

# %%
 #best params loaded up 
best_score=.899
ntrees=200 
depthmax=12 
minperleaf=2

# %%
rf_feature_imp = pd.Series(rf.feature_importances_,index=dims_add).sort_values(ascending=False)

# %%
y_train_pred = rf.predict(new_train)
y_test_pred=rf.predict(new_test)
rf_scores = rf.predict_proba(new_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Train Accuracy: %.2f%%"%(metrics.accuracy_score(yy_train, y_train_pred)*100))
print("Test Accuracy: %.2f%%"%(metrics.accuracy_score(yy_test, y_test_pred)*100))
# Out:
# Train Accuracy: 97.08%
# Test Accuracy: 89.69%

# %%
colordict = dict(
    n100 = 'red', pe = 'red', n9 = 'red', n400 = 'red', id_plus_dr_hit = 'red', 
    x = 'deepskyblue', y='deepskyblue', z='deepskyblue', u='deepskyblue', v='deepskyblue', w='deepskyblue', 
    closestPMT = 'deepskyblue', 
    azimuth_ks = 'orange', beta_one='orange', beta_two='orange', beta_three='orange', beta_four='orange', beta_five='orange', beta_six='orange', 
    closestPMT_next = 'hotpink', dt_next_us = 'hotpink', good_dir_next = 'hotpink', azimuth_ks_next = 'hotpink', 
    n9_next = 'hotpink', n100_next = 'hotpink', drNextr = 'hotpink', 
    good_pos = 'mediumseagreen', good_dir = 'mediumseagreen',
)
colors = [colordict[c] if c in colordict else 'k' for c in rf_feature_imp.index]

# %%
# Creating a bar plot
plt.figure(figsize=(4, 6))
ax = sns.barplot(x=rf_feature_imp, 
                 y=rf_feature_imp.index, 
                 palette = colors, 
                )

ax.yaxis.set_ticklabels(rf_feature_imp.index,)
plt.xlabel('Feature Importance Score')
plt.xscale('log')
plt.xlim(1e-3, .2)
# plt.ylabel('Features')
plt.title("Feature Importance: Random Forest \nFast-neutron/IBD in H$_2$O")
plt.show()

# %%
ml = ML_Evaluation(y_test, rf_scores)
ml.draw_confmat(extra_title='\nH$_2$O: Random Forest')
rf_tpr, rf_fpr, rf_thresholds = ml.draw_roc(extra_title='\nH$_2$O: Random Forest')
results = dict()
results['rf'] = dict(scores=rf_scores, tpr=rf_tpr, fpr=rf_fpr, thresholds=rf_thresholds)
acceptances = dict(fpr=rf_fpr, tpr=rf_tpr)
# save_obj(acceptances, 'rates')
quick_analysis(acceptances, medium='h2o')

# %%
kw = dict(histtype='step', bins=50, range=[0,1])
plt.hist(rf_scores[:,1][val.y==0], **kw, label='first event from fast-n')
plt.hist(rf_scores[:,1][val.y==1], **kw, label='IBD positron')
plt.xlabel('Random Forest Output Probability', fontsize=14)
plt.ylabel('Counts', fontsize=12)
plt.yscale('log')
plt.legend()
plt.show()

# %%
precision_recall_fscore_support(y_test, np.round(rf_scores[:,1]))
# Out:
# (array([0.9280397 , 0.86953353]),
#  array([0.86241353, 0.93203125]),
#  array([0.8940239 , 0.89969834]),
#  array([1301, 1280]))

# %% [markdown]
# ## Trying more rigorous AdaBoost

# %%
n_trees = np.array([5, 10, 20, 50, 100])
max_depth = np.array([2, 4, 6, 8])
min_per_leaf = np.array([1, 10, 50])
n_boost = np.array([10, 15, 20, 50, 100])

# %%
train_acc_bf = np.zeros((len(n_trees), len(max_depth), len(min_per_leaf), len(n_boost), ))
test_acc_bf = np.zeros((len(n_trees), len(max_depth), len(min_per_leaf), len(n_boost), ))

# %%
for i, ntrees in enumerate(n_trees):
    for j, depthmax in enumerate(max_depth):
        for k, minsperleaf in enumerate(min_per_leaf):
            for l, nboost in enumerate(n_boost):
                if train_acc_bf[i,j,k,l]>0:
                    continue
                print(f'Calculating: n_bc={ntrees} max_depth:{depthmax} min_samples_per_leaf:{minsperleaf} num boosts:{nboost}')
                clf=RandomForestClassifier(n_estimators=ntrees, 
                    max_depth=depthmax, 
                    bootstrap=True, min_samples_leaf=minsperleaf,
                )
                bf = AdaBoostClassifier(base_estimator=clf, n_estimators=nboost, random_state=43)
                bf.fit(new_train,yy_train)
                train_acc_bf[i,j,k,l] = bf.score(new_train, y_train)
                test_acc_bf[i,j,k,l] = bf.score(new_test, y_test)
                print("Train Acc: %.4f"%(train_acc_bf[i,j,k,l]))
                print("Val.  Acc: %.4f"%(test_acc_bf[i,j,k,l]))
# Out:
# Calculating: n_bc=5 max_depth:2 min_samples_per_leaf:1 num boosts:10
# Train Acc: 0.9004
# Val.  Acc: 0.8977
# Calculating: n_bc=5 max_depth:2 min_samples_per_leaf:1 num boosts:15
# Train Acc: 0.9056
# Val.  Acc: 0.8993
# Calculating: n_bc=5 max_depth:2 min_samples_per_leaf:1 num boosts:20
# Train Acc: 0.9075
# Val.  Acc: 0.9031
# Calculating: n_bc=5 max_depth:2 min_samples_per_leaf:1 num boosts:50
# Train Acc: 0.9186
# Val.  Acc: 0.9000
# Calculating: n_bc=5 max_depth:2 min_samples_per_leaf:1 num boosts:100
# Train Acc: 0.9341
# Val.  Acc: 0.8981
# Calculating: n_bc=5 max_depth:2 min_samples_per_leaf:10 num boosts:10
# Train Acc: 0.9014
# Val.  Acc: 0.8973
# Calculating: n_bc=5 max_depth:2 min_samples_per_leaf:10 num boosts:15
# Train Acc: 0.9061
# Val.  Acc: 0.8997
# Calculating: n_bc=5 max_depth:2 min_samples_per_leaf:10 num boosts:20
# Train Acc: 0.9074
# Val.  Acc: 0.9051
# Calculating: n_bc=5 max_depth:2 min_samples_per_leaf:10 num boosts:50
# Train Acc: 0.9180
# Val.  Acc: 0.8954
# Calculating: n_bc=5 max_depth:2 min_samples_per_leaf:10 num boosts:100
# Train Acc: 0.9339
# Val.  Acc: 0.8997
# Calculating: n_bc=5 max_depth:2 min_samples_per_leaf:50 num boosts:10
# Train Acc: 0.9009
# Val.  Acc: 0.8973
# Calculating: n_bc=5 max_depth:2 min_samples_per_leaf:50 num boosts:15
# Train Acc: 0.9060
# Val.  Acc: 0.9020
# Calculating: n_bc=5 max_depth:2 min_samples_per_leaf:50 num boosts:20
# Train Acc: 0.9093
# Val.  Acc: 0.9051
# Calculating: n_bc=5 max_depth:2 min_samples_per_leaf:50 num boosts:50
# Train Acc: 0.9181
# Val.  Acc: 0.8993
# Calculating: n_bc=5 max_depth:2 min_samples_per_leaf:50 num boosts:100
# Train Acc: 0.9336
# Val.  Acc: 0.8962
# Calculating: n_bc=5 max_depth:4 min_samples_per_leaf:1 num boosts:10
# Train Acc: 0.9204
# Val.  Acc: 0.8958
# Calculating: n_bc=5 max_depth:4 min_samples_per_leaf:1 num boosts:15
# Train Acc: 0.9299
# Val.  Acc: 0.8962
# Calculating: n_bc=5 max_depth:4 min_samples_per_leaf:1 num boosts:20
# Train Acc: 0.9403
# Val.  Acc: 0.8977
# Calculating: n_bc=5 max_depth:4 min_samples_per_leaf:1 num boosts:50
# Train Acc: 0.9860
# Val.  Acc: 0.8969
# Calculating: n_bc=5 max_depth:4 min_samples_per_leaf:1 num boosts:100
# Train Acc: 1.0000
# Val.  Acc: 0.8935
# Calculating: n_bc=5 max_depth:4 min_samples_per_leaf:10 num boosts:10
# Train Acc: 0.9196
# Val.  Acc: 0.9004
# Calculating: n_bc=5 max_depth:4 min_samples_per_leaf:10 num boosts:15
# Train Acc: 0.9287
# Val.  Acc: 0.8969
# Calculating: n_bc=5 max_depth:4 min_samples_per_leaf:10 num boosts:20
# Train Acc: 0.9362
# Val.  Acc: 0.8942
# Calculating: n_bc=5 max_depth:4 min_samples_per_leaf:10 num boosts:50
# Train Acc: 0.9840
# Val.  Acc: 0.8993
# Calculating: n_bc=5 max_depth:4 min_samples_per_leaf:10 num boosts:100
# Train Acc: 0.9999
# Val.  Acc: 0.8938
# Calculating: n_bc=5 max_depth:4 min_samples_per_leaf:50 num boosts:10
# Train Acc: 0.9169
# Val.  Acc: 0.9004
# Calculating: n_bc=5 max_depth:4 min_samples_per_leaf:50 num boosts:15
# Train Acc: 0.9247
# Val.  Acc: 0.8981
# Calculating: n_bc=5 max_depth:4 min_samples_per_leaf:50 num boosts:20
# Train Acc: 0.9330
# Val.  Acc: 0.8958
# Calculating: n_bc=5 max_depth:4 min_samples_per_leaf:50 num boosts:50
# Train Acc: 0.9720
# Val.  Acc: 0.8958
# Calculating: n_bc=5 max_depth:4 min_samples_per_leaf:50 num boosts:100
# Train Acc: 0.9996
# Val.  Acc: 0.8962
# Calculating: n_bc=5 max_depth:6 min_samples_per_leaf:1 num boosts:10
# Train Acc: 0.9540
# Val.  Acc: 0.8950
# Calculating: n_bc=5 max_depth:6 min_samples_per_leaf:1 num boosts:15
# Train Acc: 0.9746
# Val.  Acc: 0.8981
# Calculating: n_bc=5 max_depth:6 min_samples_per_leaf:1 num boosts:20
# Train Acc: 0.9898
# Val.  Acc: 0.8985
# Calculating: n_bc=5 max_depth:6 min_samples_per_leaf:1 num boosts:50
# Train Acc: 1.0000
# Val.  Acc: 0.8958
# Calculating: n_bc=5 max_depth:6 min_samples_per_leaf:1 num boosts:100
# Train Acc: 1.0000
# Val.  Acc: 0.8989
# Calculating: n_bc=5 max_depth:6 min_samples_per_leaf:10 num boosts:10
# Train Acc: 0.9497
# Val.  Acc: 0.9012
# Calculating: n_bc=5 max_depth:6 min_samples_per_leaf:10 num boosts:15
# Train Acc: 0.9709
# Val.  Acc: 0.8981
# Calculating: n_bc=5 max_depth:6 min_samples_per_leaf:10 num boosts:20
# Train Acc: 0.9879
# Val.  Acc: 0.8989
# Calculating: n_bc=5 max_depth:6 min_samples_per_leaf:10 num boosts:50
# Train Acc: 1.0000
# Val.  Acc: 0.9004
# Calculating: n_bc=5 max_depth:6 min_samples_per_leaf:10 num boosts:100
# Train Acc: 1.0000
# Val.  Acc: 0.9004
# Calculating: n_bc=5 max_depth:6 min_samples_per_leaf:50 num boosts:10
# Train Acc: 0.9379
# Val.  Acc: 0.9016
# Calculating: n_bc=5 max_depth:6 min_samples_per_leaf:50 num boosts:15
# Train Acc: 0.9565
# Val.  Acc: 0.9024
# Calculating: n_bc=5 max_depth:6 min_samples_per_leaf:50 num boosts:20
# Train Acc: 0.9682
# Val.  Acc: 0.9024
# Calculating: n_bc=5 max_depth:6 min_samples_per_leaf:50 num boosts:50
# Train Acc: 1.0000
# Val.  Acc: 0.9004
# Calculating: n_bc=5 max_depth:6 min_samples_per_leaf:50 num boosts:100
# Train Acc: 1.0000
# Val.  Acc: 0.9024
# Calculating: n_bc=5 max_depth:8 min_samples_per_leaf:1 num boosts:10
# Train Acc: 0.9961
# Val.  Acc: 0.8935
# Calculating: n_bc=5 max_depth:8 min_samples_per_leaf:1 num boosts:15
# Train Acc: 1.0000
# Val.  Acc: 0.8962
# Calculating: n_bc=5 max_depth:8 min_samples_per_leaf:1 num boosts:20
# Train Acc: 1.0000
# Val.  Acc: 0.8966
# Calculating: n_bc=5 max_depth:8 min_samples_per_leaf:1 num boosts:50
# Train Acc: 1.0000
# Val.  Acc: 0.9020
# Calculating: n_bc=5 max_depth:8 min_samples_per_leaf:1 num boosts:100
# Train Acc: 1.0000
# Val.  Acc: 0.8973
# Calculating: n_bc=5 max_depth:8 min_samples_per_leaf:10 num boosts:10
# Train Acc: 0.9868
# Val.  Acc: 0.8958
# Calculating: n_bc=5 max_depth:8 min_samples_per_leaf:10 num boosts:15
# Train Acc: 0.9992
# Val.  Acc: 0.8997
# Calculating: n_bc=5 max_depth:8 min_samples_per_leaf:10 num boosts:20
# Train Acc: 0.9997
# Val.  Acc: 0.9024
# Calculating: n_bc=5 max_depth:8 min_samples_per_leaf:10 num boosts:50
# Train Acc: 1.0000
# Val.  Acc: 0.8958
# Calculating: n_bc=5 max_depth:8 min_samples_per_leaf:10 num boosts:100
# Train Acc: 1.0000
# Val.  Acc: 0.9004
# Calculating: n_bc=5 max_depth:8 min_samples_per_leaf:50 num boosts:10
# Train Acc: 0.9531
# Val.  Acc: 0.8958
# Calculating: n_bc=5 max_depth:8 min_samples_per_leaf:50 num boosts:15
# Train Acc: 0.9771
# Val.  Acc: 0.9012
# Calculating: n_bc=5 max_depth:8 min_samples_per_leaf:50 num boosts:20
# Train Acc: 0.9924
# Val.  Acc: 0.8985
# Calculating: n_bc=5 max_depth:8 min_samples_per_leaf:50 num boosts:50
# Train Acc: 1.0000
# Val.  Acc: 0.8888
# Calculating: n_bc=5 max_depth:8 min_samples_per_leaf:50 num boosts:100
# Train Acc: 1.0000
# Val.  Acc: 0.8946
# Calculating: n_bc=10 max_depth:2 min_samples_per_leaf:1 num boosts:10
# Train Acc: 0.9014
# Val.  Acc: 0.8993
# Calculating: n_bc=10 max_depth:2 min_samples_per_leaf:1 num boosts:15
# Train Acc: 0.9061
# Val.  Acc: 0.9035
# Calculating: n_bc=10 max_depth:2 min_samples_per_leaf:1 num boosts:20
# Train Acc: 0.9113
# Val.  Acc: 0.9028
# Calculating: n_bc=10 max_depth:2 min_samples_per_leaf:1 num boosts:50
# Train Acc: 0.9224
# Val.  Acc: 0.8993
# Calculating: n_bc=10 max_depth:2 min_samples_per_leaf:1 num boosts:100
# Train Acc: 0.9376
# Val.  Acc: 0.9008
# Calculating: n_bc=10 max_depth:2 min_samples_per_leaf:10 num boosts:10
# Train Acc: 0.9014
# Val.  Acc: 0.8993
# Calculating: n_bc=10 max_depth:2 min_samples_per_leaf:10 num boosts:15
# Train Acc: 0.9060
# Val.  Acc: 0.9028
# Calculating: n_bc=10 max_depth:2 min_samples_per_leaf:10 num boosts:20
# Train Acc: 0.9107
# Val.  Acc: 0.9035
# Calculating: n_bc=10 max_depth:2 min_samples_per_leaf:10 num boosts:50
# Train Acc: 0.9220
# Val.  Acc: 0.8997
# Calculating: n_bc=10 max_depth:2 min_samples_per_leaf:10 num boosts:100
# Train Acc: 0.9361
# Val.  Acc: 0.8977
# Calculating: n_bc=10 max_depth:2 min_samples_per_leaf:50 num boosts:10
# Train Acc: 0.9012
# Val.  Acc: 0.9000
# Calculating: n_bc=10 max_depth:2 min_samples_per_leaf:50 num boosts:15
# Train Acc: 0.9071
# Val.  Acc: 0.9028
# Calculating: n_bc=10 max_depth:2 min_samples_per_leaf:50 num boosts:20
# Train Acc: 0.9089
# Val.  Acc: 0.9028
# Calculating: n_bc=10 max_depth:2 min_samples_per_leaf:50 num boosts:50
# Train Acc: 0.9211
# Val.  Acc: 0.9024
# Calculating: n_bc=10 max_depth:2 min_samples_per_leaf:50 num boosts:100
# Train Acc: 0.9346
# Val.  Acc: 0.8938
# Calculating: n_bc=10 max_depth:4 min_samples_per_leaf:1 num boosts:10
# Train Acc: 0.9227
# Val.  Acc: 0.9008
# Calculating: n_bc=10 max_depth:4 min_samples_per_leaf:1 num boosts:15
# Train Acc: 0.9346
# Val.  Acc: 0.9055
# Calculating: n_bc=10 max_depth:4 min_samples_per_leaf:1 num boosts:20
# Train Acc: 0.9426
# Val.  Acc: 0.9031
# Calculating: n_bc=10 max_depth:4 min_samples_per_leaf:1 num boosts:50
# Train Acc: 0.9877
# Val.  Acc: 0.9039
# Calculating: n_bc=10 max_depth:4 min_samples_per_leaf:1 num boosts:100
# Train Acc: 1.0000
# Val.  Acc: 0.9008
# Calculating: n_bc=10 max_depth:4 min_samples_per_leaf:10 num boosts:10
# Train Acc: 0.9212
# Val.  Acc: 0.9008
# Calculating: n_bc=10 max_depth:4 min_samples_per_leaf:10 num boosts:15
# Train Acc: 0.9301
# Val.  Acc: 0.9039
# Calculating: n_bc=10 max_depth:4 min_samples_per_leaf:10 num boosts:20
# Train Acc: 0.9407
# Val.  Acc: 0.9047
# Calculating: n_bc=10 max_depth:4 min_samples_per_leaf:10 num boosts:50
# Train Acc: 0.9868
# Val.  Acc: 0.9020
# Calculating: n_bc=10 max_depth:4 min_samples_per_leaf:10 num boosts:100
# Train Acc: 1.0000
# Val.  Acc: 0.9004
# Calculating: n_bc=10 max_depth:4 min_samples_per_leaf:50 num boosts:10
# Train Acc: 0.9225
# Val.  Acc: 0.9012
# Calculating: n_bc=10 max_depth:4 min_samples_per_leaf:50 num boosts:15
# Train Acc: 0.9305
# Val.  Acc: 0.9047
# Calculating: n_bc=10 max_depth:4 min_samples_per_leaf:50 num boosts:20
# Train Acc: 0.9392
# Val.  Acc: 0.9055
# Calculating: n_bc=10 max_depth:4 min_samples_per_leaf:50 num boosts:50
# Train Acc: 0.9780
# Val.  Acc: 0.9043
# Calculating: n_bc=10 max_depth:4 min_samples_per_leaf:50 num boosts:100
# Train Acc: 0.9999
# Val.  Acc: 0.9024
# Calculating: n_bc=10 max_depth:6 min_samples_per_leaf:1 num boosts:10
# Train Acc: 0.9590
# Val.  Acc: 0.8993
# Calculating: n_bc=10 max_depth:6 min_samples_per_leaf:1 num boosts:15
# Train Acc: 0.9800
# Val.  Acc: 0.9008
# Calculating: n_bc=10 max_depth:6 min_samples_per_leaf:1 num boosts:20
# Train Acc: 0.9943
# Val.  Acc: 0.9028
# Calculating: n_bc=10 max_depth:6 min_samples_per_leaf:1 num boosts:50
# Train Acc: 1.0000
# Val.  Acc: 0.9020
# Calculating: n_bc=10 max_depth:6 min_samples_per_leaf:1 num boosts:100
# Train Acc: 1.0000
# Val.  Acc: 0.9035
# Calculating: n_bc=10 max_depth:6 min_samples_per_leaf:10 num boosts:10
# Train Acc: 0.9541
# Val.  Acc: 0.9000
# Calculating: n_bc=10 max_depth:6 min_samples_per_leaf:10 num boosts:15
# Train Acc: 0.9753
# Val.  Acc: 0.9012
# Calculating: n_bc=10 max_depth:6 min_samples_per_leaf:10 num boosts:20
# Train Acc: 0.9898
# Val.  Acc: 0.9031
# Calculating: n_bc=10 max_depth:6 min_samples_per_leaf:10 num boosts:50
# Train Acc: 1.0000
# Val.  Acc: 0.9004
# Calculating: n_bc=10 max_depth:6 min_samples_per_leaf:10 num boosts:100
# Train Acc: 1.0000
# Val.  Acc: 0.9008
# Calculating: n_bc=10 max_depth:6 min_samples_per_leaf:50 num boosts:10
# Train Acc: 0.9403
# Val.  Acc: 0.9059
# Calculating: n_bc=10 max_depth:6 min_samples_per_leaf:50 num boosts:15
# Train Acc: 0.9569
# Val.  Acc: 0.9012
# Calculating: n_bc=10 max_depth:6 min_samples_per_leaf:50 num boosts:20
# Train Acc: 0.9715
# Val.  Acc: 0.8997
# Calculating: n_bc=10 max_depth:6 min_samples_per_leaf:50 num boosts:50
# Train Acc: 1.0000
# Val.  Acc: 0.8985
# Calculating: n_bc=10 max_depth:6 min_samples_per_leaf:50 num boosts:100
# Train Acc: 1.0000
# Val.  Acc: 0.8997
# Calculating: n_bc=10 max_depth:8 min_samples_per_leaf:1 num boosts:10
# Train Acc: 0.9946
# Val.  Acc: 0.9004
# Calculating: n_bc=10 max_depth:8 min_samples_per_leaf:1 num boosts:15
# Train Acc: 0.9999
# Val.  Acc: 0.8989
# Calculating: n_bc=10 max_depth:8 min_samples_per_leaf:1 num boosts:20
# Train Acc: 1.0000
# Val.  Acc: 0.9028
# Calculating: n_bc=10 max_depth:8 min_samples_per_leaf:1 num boosts:50
# Train Acc: 1.0000
# Val.  Acc: 0.9039
# Calculating: n_bc=10 max_depth:8 min_samples_per_leaf:1 num boosts:100
# Train Acc: 1.0000
# Val.  Acc: 0.9028
# Calculating: n_bc=10 max_depth:8 min_samples_per_leaf:10 num boosts:10
# Train Acc: 0.9875
# Val.  Acc: 0.8997
# Calculating: n_bc=10 max_depth:8 min_samples_per_leaf:10 num boosts:15
# Train Acc: 0.9990
# Val.  Acc: 0.9012
# Calculating: n_bc=10 max_depth:8 min_samples_per_leaf:10 num boosts:20
# Train Acc: 1.0000
# Val.  Acc: 0.8969
# Calculating: n_bc=10 max_depth:8 min_samples_per_leaf:10 num boosts:50
# Train Acc: 1.0000
# Val.  Acc: 0.8977
# Calculating: n_bc=10 max_depth:8 min_samples_per_leaf:10 num boosts:100
# Train Acc: 1.0000
# Val.  Acc: 0.9008
# Calculating: n_bc=10 max_depth:8 min_samples_per_leaf:50 num boosts:10
# Train Acc: 0.9572
# Val.  Acc: 0.9012
# Calculating: n_bc=10 max_depth:8 min_samples_per_leaf:50 num boosts:15
# Train Acc: 0.9797
# Val.  Acc: 0.8966
# Calculating: n_bc=10 max_depth:8 min_samples_per_leaf:50 num boosts:20
# Train Acc: 0.9942
# Val.  Acc: 0.8969
# Calculating: n_bc=10 max_depth:8 min_samples_per_leaf:50 num boosts:50
# Train Acc: 1.0000
# Val.  Acc: 0.8981
# Calculating: n_bc=10 max_depth:8 min_samples_per_leaf:50 num boosts:100
# Train Acc: 1.0000
# Val.  Acc: 0.8969
# Calculating: n_bc=20 max_depth:2 min_samples_per_leaf:1 num boosts:10
# Train Acc: 0.9022
# Val.  Acc: 0.8997
# Calculating: n_bc=20 max_depth:2 min_samples_per_leaf:1 num boosts:15
# Train Acc: 0.9079
# Val.  Acc: 0.9016
# Calculating: n_bc=20 max_depth:2 min_samples_per_leaf:1 num boosts:20
# Train Acc: 0.9097
# Val.  Acc: 0.9043
# Calculating: n_bc=20 max_depth:2 min_samples_per_leaf:1 num boosts:50
# Train Acc: 0.9240
# Val.  Acc: 0.8997
# Calculating: n_bc=20 max_depth:2 min_samples_per_leaf:1 num boosts:100
# Train Acc: 0.9392
# Val.  Acc: 0.9012
# Calculating: n_bc=20 max_depth:2 min_samples_per_leaf:10 num boosts:10
# Train Acc: 0.9022
# Val.  Acc: 0.8997
# Calculating: n_bc=20 max_depth:2 min_samples_per_leaf:10 num boosts:15
# Train Acc: 0.9070
# Val.  Acc: 0.9016
# Calculating: n_bc=20 max_depth:2 min_samples_per_leaf:10 num boosts:20
# Train Acc: 0.9100
# Val.  Acc: 0.9024
# Calculating: n_bc=20 max_depth:2 min_samples_per_leaf:10 num boosts:50
# Train Acc: 0.9238
# Val.  Acc: 0.9016
# Calculating: n_bc=20 max_depth:2 min_samples_per_leaf:10 num boosts:100
# Train Acc: 0.9386
# Val.  Acc: 0.8985
# Calculating: n_bc=20 max_depth:2 min_samples_per_leaf:50 num boosts:10
# Train Acc: 0.9025
# Val.  Acc: 0.9008
# Calculating: n_bc=20 max_depth:2 min_samples_per_leaf:50 num boosts:15
# Train Acc: 0.9075
# Val.  Acc: 0.9039
# Calculating: n_bc=20 max_depth:2 min_samples_per_leaf:50 num boosts:20
# Train Acc: 0.9103
# Val.  Acc: 0.9024
# Calculating: n_bc=20 max_depth:2 min_samples_per_leaf:50 num boosts:50
# Train Acc: 0.9206
# Val.  Acc: 0.9004
# Calculating: n_bc=20 max_depth:2 min_samples_per_leaf:50 num boosts:100
# Train Acc: 0.9350
# Val.  Acc: 0.9000
# Calculating: n_bc=20 max_depth:4 min_samples_per_leaf:1 num boosts:10
# Train Acc: 0.9227
# Val.  Acc: 0.9024
# Calculating: n_bc=20 max_depth:4 min_samples_per_leaf:1 num boosts:15
# Train Acc: 0.9333
# Val.  Acc: 0.9066
# Calculating: n_bc=20 max_depth:4 min_samples_per_leaf:1 num boosts:20
# Train Acc: 0.9424
# Val.  Acc: 0.9024
# Calculating: n_bc=20 max_depth:4 min_samples_per_leaf:1 num boosts:50
# Train Acc: 0.9886
# Val.  Acc: 0.9024
# Calculating: n_bc=20 max_depth:4 min_samples_per_leaf:1 num boosts:100
# Train Acc: 1.0000
# Val.  Acc: 0.8989
# Calculating: n_bc=20 max_depth:4 min_samples_per_leaf:10 num boosts:10
# Train Acc: 0.9238
# Val.  Acc: 0.9043
# Calculating: n_bc=20 max_depth:4 min_samples_per_leaf:10 num boosts:15
# Train Acc: 0.9331
# Val.  Acc: 0.9039
# Calculating: n_bc=20 max_depth:4 min_samples_per_leaf:10 num boosts:20
# Train Acc: 0.9423
# Val.  Acc: 0.9004
# Calculating: n_bc=20 max_depth:4 min_samples_per_leaf:10 num boosts:50
# Train Acc: 0.9881
# Val.  Acc: 0.9031
# Calculating: n_bc=20 max_depth:4 min_samples_per_leaf:10 num boosts:100
# Train Acc: 1.0000
# Val.  Acc: 0.9012
# Calculating: n_bc=20 max_depth:4 min_samples_per_leaf:50 num boosts:10
# Train Acc: 0.9191
# Val.  Acc: 0.9012
# Calculating: n_bc=20 max_depth:4 min_samples_per_leaf:50 num boosts:15
# Train Acc: 0.9284
# Val.  Acc: 0.9000
# Calculating: n_bc=20 max_depth:4 min_samples_per_leaf:50 num boosts:20
# Train Acc: 0.9358
# Val.  Acc: 0.9024
# Calculating: n_bc=20 max_depth:4 min_samples_per_leaf:50 num boosts:50
# Train Acc: 0.9787
# Val.  Acc: 0.8985
# Calculating: n_bc=20 max_depth:4 min_samples_per_leaf:50 num boosts:100
# Train Acc: 1.0000
# Val.  Acc: 0.9008
# Calculating: n_bc=20 max_depth:6 min_samples_per_leaf:1 num boosts:10
# Train Acc: 0.9596
# Val.  Acc: 0.9000
# Calculating: n_bc=20 max_depth:6 min_samples_per_leaf:1 num boosts:15
# Train Acc: 0.9818
# Val.  Acc: 0.8989
# Calculating: n_bc=20 max_depth:6 min_samples_per_leaf:1 num boosts:20
# Train Acc: 0.9943
# Val.  Acc: 0.9016
# Calculating: n_bc=20 max_depth:6 min_samples_per_leaf:1 num boosts:50
# Train Acc: 1.0000
# Val.  Acc: 0.9004
# Calculating: n_bc=20 max_depth:6 min_samples_per_leaf:1 num boosts:100
# Train Acc: 1.0000
# Val.  Acc: 0.9016
# Calculating: n_bc=20 max_depth:6 min_samples_per_leaf:10 num boosts:10
# Train Acc: 0.9553
# Val.  Acc: 0.9031
# Calculating: n_bc=20 max_depth:6 min_samples_per_leaf:10 num boosts:15
# Train Acc: 0.9760
# Val.  Acc: 0.9051
# Calculating: n_bc=20 max_depth:6 min_samples_per_leaf:10 num boosts:20
# Train Acc: 0.9903
# Val.  Acc: 0.9043
# Calculating: n_bc=20 max_depth:6 min_samples_per_leaf:10 num boosts:50
# Train Acc: 1.0000
# Val.  Acc: 0.9000
# Calculating: n_bc=20 max_depth:6 min_samples_per_leaf:10 num boosts:100
# Train Acc: 1.0000
# Val.  Acc: 0.9024
# Calculating: n_bc=20 max_depth:6 min_samples_per_leaf:50 num boosts:10
# Train Acc: 0.9402
# Val.  Acc: 0.9059
# Calculating: n_bc=20 max_depth:6 min_samples_per_leaf:50 num boosts:15
# Train Acc: 0.9587
# Val.  Acc: 0.9043
# Calculating: n_bc=20 max_depth:6 min_samples_per_leaf:50 num boosts:20
# Train Acc: 0.9738
# Val.  Acc: 0.9062
# Calculating: n_bc=20 max_depth:6 min_samples_per_leaf:50 num boosts:50
# Train Acc: 1.0000
# Val.  Acc: 0.9028
# Calculating: n_bc=20 max_depth:6 min_samples_per_leaf:50 num boosts:100
# Train Acc: 1.0000
# Val.  Acc: 0.9012
# Calculating: n_bc=20 max_depth:8 min_samples_per_leaf:1 num boosts:10
# Train Acc: 0.9947
# Val.  Acc: 0.9066
# Calculating: n_bc=20 max_depth:8 min_samples_per_leaf:1 num boosts:15
# Train Acc: 1.0000
# Val.  Acc: 0.9074
# Calculating: n_bc=20 max_depth:8 min_samples_per_leaf:1 num boosts:20
# Train Acc: 1.0000
# Val.  Acc: 0.9066
# Calculating: n_bc=20 max_depth:8 min_samples_per_leaf:1 num boosts:50
# Train Acc: 1.0000
# Val.  Acc: 0.9035
# Calculating: n_bc=20 max_depth:8 min_samples_per_leaf:1 num boosts:100
# Train Acc: 1.0000
# Val.  Acc: 0.9028
# Calculating: n_bc=20 max_depth:8 min_samples_per_leaf:10 num boosts:10
# Train Acc: 0.9888
# Val.  Acc: 0.9039
# Calculating: n_bc=20 max_depth:8 min_samples_per_leaf:10 num boosts:15
# Train Acc: 0.9996
# Val.  Acc: 0.9047
# Calculating: n_bc=20 max_depth:8 min_samples_per_leaf:10 num boosts:20
# Train Acc: 1.0000
# Val.  Acc: 0.9039
# Calculating: n_bc=20 max_depth:8 min_samples_per_leaf:10 num boosts:50
# Train Acc: 1.0000
# Val.  Acc: 0.9062
# Calculating: n_bc=20 max_depth:8 min_samples_per_leaf:10 num boosts:100
# Train Acc: 1.0000
# Val.  Acc: 0.9047
# Calculating: n_bc=20 max_depth:8 min_samples_per_leaf:50 num boosts:10
# Train Acc: 0.9576
# Val.  Acc: 0.8997
# Calculating: n_bc=20 max_depth:8 min_samples_per_leaf:50 num boosts:15
# Train Acc: 0.9818
# Val.  Acc: 0.9004
# Calculating: n_bc=20 max_depth:8 min_samples_per_leaf:50 num boosts:20
# Train Acc: 0.9969
# Val.  Acc: 0.8997
# Calculating: n_bc=20 max_depth:8 min_samples_per_leaf:50 num boosts:50
# Train Acc: 1.0000
# Val.  Acc: 0.8989
# Calculating: n_bc=20 max_depth:8 min_samples_per_leaf:50 num boosts:100
# Train Acc: 1.0000
# Val.  Acc: 0.8977
# Calculating: n_bc=50 max_depth:2 min_samples_per_leaf:1 num boosts:10
# Train Acc: 0.9026
# Val.  Acc: 0.8973
# Calculating: n_bc=50 max_depth:2 min_samples_per_leaf:1 num boosts:15
# Train Acc: 0.9096
# Val.  Acc: 0.9039
# Calculating: n_bc=50 max_depth:2 min_samples_per_leaf:1 num boosts:20
# Train Acc: 0.9118
# Val.  Acc: 0.9020
# Calculating: n_bc=50 max_depth:2 min_samples_per_leaf:1 num boosts:50
# Train Acc: 0.9246
# Val.  Acc: 0.9020
# Calculating: n_bc=50 max_depth:2 min_samples_per_leaf:1 num boosts:100
# Train Acc: 0.9401
# Val.  Acc: 0.9024
# Calculating: n_bc=50 max_depth:2 min_samples_per_leaf:10 num boosts:10
# Train Acc: 0.9025
# Val.  Acc: 0.8973
# Calculating: n_bc=50 max_depth:2 min_samples_per_leaf:10 num boosts:15
# Train Acc: 0.9093
# Val.  Acc: 0.9043
# Calculating: n_bc=50 max_depth:2 min_samples_per_leaf:10 num boosts:20
# Train Acc: 0.9111
# Val.  Acc: 0.9020
# Calculating: n_bc=50 max_depth:2 min_samples_per_leaf:10 num boosts:50
# Train Acc: 0.9239
# Val.  Acc: 0.9031
# Calculating: n_bc=50 max_depth:2 min_samples_per_leaf:10 num boosts:100
# Train Acc: 0.9394
# Val.  Acc: 0.9043
# Calculating: n_bc=50 max_depth:2 min_samples_per_leaf:50 num boosts:10
# Train Acc: 0.9030
# Val.  Acc: 0.9000
# Calculating: n_bc=50 max_depth:2 min_samples_per_leaf:50 num boosts:15
# Train Acc: 0.9083
# Val.  Acc: 0.9047
# Calculating: n_bc=50 max_depth:2 min_samples_per_leaf:50 num boosts:20
# Train Acc: 0.9115
# Val.  Acc: 0.9016
# Calculating: n_bc=50 max_depth:2 min_samples_per_leaf:50 num boosts:50
# Train Acc: 0.9229
# Val.  Acc: 0.9028
# Calculating: n_bc=50 max_depth:2 min_samples_per_leaf:50 num boosts:100
# Train Acc: 0.9359
# Val.  Acc: 0.9031
# Calculating: n_bc=50 max_depth:4 min_samples_per_leaf:1 num boosts:10
# Train Acc: 0.9256
# Val.  Acc: 0.9059
# Calculating: n_bc=50 max_depth:4 min_samples_per_leaf:1 num boosts:15
# Train Acc: 0.9349
# Val.  Acc: 0.9043
# Calculating: n_bc=50 max_depth:4 min_samples_per_leaf:1 num boosts:20
# Train Acc: 0.9451
# Val.  Acc: 0.9047
# Calculating: n_bc=50 max_depth:4 min_samples_per_leaf:1 num boosts:50
# Train Acc: 0.9901
# Val.  Acc: 0.9028
# Calculating: n_bc=50 max_depth:4 min_samples_per_leaf:1 num boosts:100
# Train Acc: 1.0000
# Val.  Acc: 0.9008
# Calculating: n_bc=50 max_depth:4 min_samples_per_leaf:10 num boosts:10
# Train Acc: 0.9248
# Val.  Acc: 0.9043
# Calculating: n_bc=50 max_depth:4 min_samples_per_leaf:10 num boosts:15
# Train Acc: 0.9340
# Val.  Acc: 0.9043
# Calculating: n_bc=50 max_depth:4 min_samples_per_leaf:10 num boosts:20
# Train Acc: 0.9446
# Val.  Acc: 0.9070
# Calculating: n_bc=50 max_depth:4 min_samples_per_leaf:10 num boosts:50
# Train Acc: 0.9884
# Val.  Acc: 0.9047
# Calculating: n_bc=50 max_depth:4 min_samples_per_leaf:10 num boosts:100
# Train Acc: 1.0000
# Val.  Acc: 0.9043
# Calculating: n_bc=50 max_depth:4 min_samples_per_leaf:50 num boosts:10
# Train Acc: 0.9203
# Val.  Acc: 0.9016
# Calculating: n_bc=50 max_depth:4 min_samples_per_leaf:50 num boosts:15
# Train Acc: 0.9273
# Val.  Acc: 0.9031
# Calculating: n_bc=50 max_depth:4 min_samples_per_leaf:50 num boosts:20
# Train Acc: 0.9375
# Val.  Acc: 0.9035
# Calculating: n_bc=50 max_depth:4 min_samples_per_leaf:50 num boosts:50
# Train Acc: 0.9793
# Val.  Acc: 0.8997
# Calculating: n_bc=50 max_depth:4 min_samples_per_leaf:50 num boosts:100
# Train Acc: 1.0000
# Val.  Acc: 0.9004
# Calculating: n_bc=50 max_depth:6 min_samples_per_leaf:1 num boosts:10
# Train Acc: 0.9616
# Val.  Acc: 0.9024
# Calculating: n_bc=50 max_depth:6 min_samples_per_leaf:1 num boosts:15
# Train Acc: 0.9836
# Val.  Acc: 0.9055
# Calculating: n_bc=50 max_depth:6 min_samples_per_leaf:1 num boosts:20
# Train Acc: 0.9955
# Val.  Acc: 0.9093
# Calculating: n_bc=50 max_depth:6 min_samples_per_leaf:1 num boosts:50
# Train Acc: 1.0000
# Val.  Acc: 0.9059
# Calculating: n_bc=50 max_depth:6 min_samples_per_leaf:1 num boosts:100
# Train Acc: 1.0000
# Val.  Acc: 0.9039
# Calculating: n_bc=50 max_depth:6 min_samples_per_leaf:10 num boosts:10
# Train Acc: 0.9565
# Val.  Acc: 0.9074
# Calculating: n_bc=50 max_depth:6 min_samples_per_leaf:10 num boosts:15
# Train Acc: 0.9774
# Val.  Acc: 0.9082
# Calculating: n_bc=50 max_depth:6 min_samples_per_leaf:10 num boosts:20
# Train Acc: 0.9915
# Val.  Acc: 0.9086
# Calculating: n_bc=50 max_depth:6 min_samples_per_leaf:10 num boosts:50
# Train Acc: 1.0000
# Val.  Acc: 0.9062
# Calculating: n_bc=50 max_depth:6 min_samples_per_leaf:10 num boosts:100
# Train Acc: 1.0000
# Val.  Acc: 0.9031
# Calculating: n_bc=50 max_depth:6 min_samples_per_leaf:50 num boosts:10
# Train Acc: 0.9410
# Val.  Acc: 0.9062
# Calculating: n_bc=50 max_depth:6 min_samples_per_leaf:50 num boosts:15
# Train Acc: 0.9587
# Val.  Acc: 0.9028
# Calculating: n_bc=50 max_depth:6 min_samples_per_leaf:50 num boosts:20
# Train Acc: 0.9738
# Val.  Acc: 0.9035
# Calculating: n_bc=50 max_depth:6 min_samples_per_leaf:50 num boosts:50
# Train Acc: 1.0000
# Val.  Acc: 0.9008
# Calculating: n_bc=50 max_depth:6 min_samples_per_leaf:50 num boosts:100
# Train Acc: 1.0000
# Val.  Acc: 0.9020
# Calculating: n_bc=50 max_depth:8 min_samples_per_leaf:1 num boosts:10
# Train Acc: 0.9961
# Val.  Acc: 0.9039
# Calculating: n_bc=50 max_depth:8 min_samples_per_leaf:1 num boosts:15
# Train Acc: 1.0000
# Val.  Acc: 0.9055
# Calculating: n_bc=50 max_depth:8 min_samples_per_leaf:1 num boosts:20
# Train Acc: 1.0000
# Val.  Acc: 0.9070
# Calculating: n_bc=50 max_depth:8 min_samples_per_leaf:1 num boosts:50
# Train Acc: 1.0000
# Val.  Acc: 0.9047
# Calculating: n_bc=50 max_depth:8 min_samples_per_leaf:1 num boosts:100
# Train Acc: 1.0000
# Val.  Acc: 0.9047
# Calculating: n_bc=50 max_depth:8 min_samples_per_leaf:10 num boosts:10
# Train Acc: 0.9882
# Val.  Acc: 0.9070
# Calculating: n_bc=50 max_depth:8 min_samples_per_leaf:10 num boosts:15
# Train Acc: 0.9996
# Val.  Acc: 0.9070
# Calculating: n_bc=50 max_depth:8 min_samples_per_leaf:10 num boosts:20
# Train Acc: 1.0000
# Val.  Acc: 0.9062
# Calculating: n_bc=50 max_depth:8 min_samples_per_leaf:10 num boosts:50
# Train Acc: 1.0000
# Val.  Acc: 0.9051
# Calculating: n_bc=50 max_depth:8 min_samples_per_leaf:10 num boosts:100
# Train Acc: 1.0000
# Val.  Acc: 0.9055
# Calculating: n_bc=50 max_depth:8 min_samples_per_leaf:50 num boosts:10
# Train Acc: 0.9607
# Val.  Acc: 0.9051
# Calculating: n_bc=50 max_depth:8 min_samples_per_leaf:50 num boosts:15
# Train Acc: 0.9831
# Val.  Acc: 0.9043
# Calculating: n_bc=50 max_depth:8 min_samples_per_leaf:50 num boosts:20
# Train Acc: 0.9968
# Val.  Acc: 0.9051
# Calculating: n_bc=50 max_depth:8 min_samples_per_leaf:50 num boosts:50
# Train Acc: 1.0000
# Val.  Acc: 0.9028
# Calculating: n_bc=50 max_depth:8 min_samples_per_leaf:50 num boosts:100
# Train Acc: 1.0000
# Val.  Acc: 0.9008
# Calculating: n_bc=100 max_depth:2 min_samples_per_leaf:1 num boosts:10
# Train Acc: 0.9038
# Val.  Acc: 0.8985
# Calculating: n_bc=100 max_depth:2 min_samples_per_leaf:1 num boosts:15
# Train Acc: 0.9102
# Val.  Acc: 0.9055
# Calculating: n_bc=100 max_depth:2 min_samples_per_leaf:1 num boosts:20
# Train Acc: 0.9124
# Val.  Acc: 0.9028
# Calculating: n_bc=100 max_depth:2 min_samples_per_leaf:1 num boosts:50
# Train Acc: 0.9243
# Val.  Acc: 0.9016
# Calculating: n_bc=100 max_depth:2 min_samples_per_leaf:1 num boosts:100
# Train Acc: 0.9385
# Val.  Acc: 0.9028
# Calculating: n_bc=100 max_depth:2 min_samples_per_leaf:10 num boosts:10
# Train Acc: 0.9040
# Val.  Acc: 0.8985
# Calculating: n_bc=100 max_depth:2 min_samples_per_leaf:10 num boosts:15
# Train Acc: 0.9103
# Val.  Acc: 0.9051
# Calculating: n_bc=100 max_depth:2 min_samples_per_leaf:10 num boosts:20
# Train Acc: 0.9128
# Val.  Acc: 0.9028
# Calculating: n_bc=100 max_depth:2 min_samples_per_leaf:10 num boosts:50
# Train Acc: 0.9238
# Val.  Acc: 0.9024
# Calculating: n_bc=100 max_depth:2 min_samples_per_leaf:10 num boosts:100
# Train Acc: 0.9380
# Val.  Acc: 0.9028
# Calculating: n_bc=100 max_depth:2 min_samples_per_leaf:50 num boosts:10
# Train Acc: 0.9041
# Val.  Acc: 0.8981
# Calculating: n_bc=100 max_depth:2 min_samples_per_leaf:50 num boosts:15
# Train Acc: 0.9101
# Val.  Acc: 0.9039
# Calculating: n_bc=100 max_depth:2 min_samples_per_leaf:50 num boosts:20
# Train Acc: 0.9122
# Val.  Acc: 0.9031
# Calculating: n_bc=100 max_depth:2 min_samples_per_leaf:50 num boosts:50
# Train Acc: 0.9235
# Val.  Acc: 0.9047
# Calculating: n_bc=100 max_depth:2 min_samples_per_leaf:50 num boosts:100
# Train Acc: 0.9363
# Val.  Acc: 0.9020
# Calculating: n_bc=100 max_depth:4 min_samples_per_leaf:1 num boosts:10
# Train Acc: 0.9247
# Val.  Acc: 0.9051
# Calculating: n_bc=100 max_depth:4 min_samples_per_leaf:1 num boosts:15
# Train Acc: 0.9353
# Val.  Acc: 0.9051
# Calculating: n_bc=100 max_depth:4 min_samples_per_leaf:1 num boosts:20
# Train Acc: 0.9429
# Val.  Acc: 0.9047
# Calculating: n_bc=100 max_depth:4 min_samples_per_leaf:1 num boosts:50
# Train Acc: 0.9899
# Val.  Acc: 0.9043
# Calculating: n_bc=100 max_depth:4 min_samples_per_leaf:1 num boosts:100
# Train Acc: 1.0000
# Val.  Acc: 0.9024
# Calculating: n_bc=100 max_depth:4 min_samples_per_leaf:10 num boosts:10
# Train Acc: 0.9242
# Val.  Acc: 0.9043
# Calculating: n_bc=100 max_depth:4 min_samples_per_leaf:10 num boosts:15
# Train Acc: 0.9328
# Val.  Acc: 0.9043
# Calculating: n_bc=100 max_depth:4 min_samples_per_leaf:10 num boosts:20
# Train Acc: 0.9434
# Val.  Acc: 0.9016
# Calculating: n_bc=100 max_depth:4 min_samples_per_leaf:10 num boosts:50
# Train Acc: 0.9885
# Val.  Acc: 0.9024
# Calculating: n_bc=100 max_depth:4 min_samples_per_leaf:10 num boosts:100
# Train Acc: 1.0000
# Val.  Acc: 0.9016
# Calculating: n_bc=100 max_depth:4 min_samples_per_leaf:50 num boosts:10
# Train Acc: 0.9204
# Val.  Acc: 0.9012
# Calculating: n_bc=100 max_depth:4 min_samples_per_leaf:50 num boosts:15
# Train Acc: 0.9286
# Val.  Acc: 0.9035
# Calculating: n_bc=100 max_depth:4 min_samples_per_leaf:50 num boosts:20
# Train Acc: 0.9377
# Val.  Acc: 0.9012
# Calculating: n_bc=100 max_depth:4 min_samples_per_leaf:50 num boosts:50
# Train Acc: 0.9797
# Val.  Acc: 0.9028
# Calculating: n_bc=100 max_depth:4 min_samples_per_leaf:50 num boosts:100
# Train Acc: 1.0000
# Val.  Acc: 0.9024
# Calculating: n_bc=100 max_depth:6 min_samples_per_leaf:1 num boosts:10
# Train Acc: 0.9615
# Val.  Acc: 0.9066
# Calculating: n_bc=100 max_depth:6 min_samples_per_leaf:1 num boosts:15
# Train Acc: 0.9828
# Val.  Acc: 0.9070
# Calculating: n_bc=100 max_depth:6 min_samples_per_leaf:1 num boosts:20
# Train Acc: 0.9960
# Val.  Acc: 0.9070
# Calculating: n_bc=100 max_depth:6 min_samples_per_leaf:1 num boosts:50
# Train Acc: 1.0000
# Val.  Acc: 0.9070
# Calculating: n_bc=100 max_depth:6 min_samples_per_leaf:1 num boosts:100
# Train Acc: 1.0000
# Val.  Acc: 0.9062
# Calculating: n_bc=100 max_depth:6 min_samples_per_leaf:10 num boosts:10
# Train Acc: 0.9567
# Val.  Acc: 0.9035
# Calculating: n_bc=100 max_depth:6 min_samples_per_leaf:10 num boosts:15
# Train Acc: 0.9767
# Val.  Acc: 0.9055
# Calculating: n_bc=100 max_depth:6 min_samples_per_leaf:10 num boosts:20
# Train Acc: 0.9912
# Val.  Acc: 0.9059
# Calculating: n_bc=100 max_depth:6 min_samples_per_leaf:10 num boosts:50
# Train Acc: 1.0000
# Val.  Acc: 0.9028
# Calculating: n_bc=100 max_depth:6 min_samples_per_leaf:10 num boosts:100
# Train Acc: 1.0000
# Val.  Acc: 0.9039
# Calculating: n_bc=100 max_depth:6 min_samples_per_leaf:50 num boosts:10
# Train Acc: 0.9430
# Val.  Acc: 0.9016
# Calculating: n_bc=100 max_depth:6 min_samples_per_leaf:50 num boosts:15
# Train Acc: 0.9596
# Val.  Acc: 0.9043
# Calculating: n_bc=100 max_depth:6 min_samples_per_leaf:50 num boosts:20
# Train Acc: 0.9740
# Val.  Acc: 0.9039
# Calculating: n_bc=100 max_depth:6 min_samples_per_leaf:50 num boosts:50
# Train Acc: 1.0000
# Val.  Acc: 0.9028
# Calculating: n_bc=100 max_depth:6 min_samples_per_leaf:50 num boosts:100
# Train Acc: 1.0000
# Val.  Acc: 0.9016
# Calculating: n_bc=100 max_depth:8 min_samples_per_leaf:1 num boosts:10
# Train Acc: 0.9969
# Val.  Acc: 0.9043
# Calculating: n_bc=100 max_depth:8 min_samples_per_leaf:1 num boosts:15
# Train Acc: 1.0000
# Val.  Acc: 0.9066
# Calculating: n_bc=100 max_depth:8 min_samples_per_leaf:1 num boosts:20
# Train Acc: 1.0000
# Val.  Acc: 0.9074
# Calculating: n_bc=100 max_depth:8 min_samples_per_leaf:1 num boosts:50
# Train Acc: 1.0000
# Val.  Acc: 0.9039
# Calculating: n_bc=100 max_depth:8 min_samples_per_leaf:1 num boosts:100
# Train Acc: 1.0000
# Val.  Acc: 0.9035
# Calculating: n_bc=100 max_depth:8 min_samples_per_leaf:10 num boosts:10
# Train Acc: 0.9893
# Val.  Acc: 0.9024
# Calculating: n_bc=100 max_depth:8 min_samples_per_leaf:10 num boosts:15
# Train Acc: 0.9997
# Val.  Acc: 0.9031
# Calculating: n_bc=100 max_depth:8 min_samples_per_leaf:10 num boosts:20
# Train Acc: 1.0000
# Val.  Acc: 0.9055
# Calculating: n_bc=100 max_depth:8 min_samples_per_leaf:10 num boosts:50
# Train Acc: 1.0000
# Val.  Acc: 0.9051
# Calculating: n_bc=100 max_depth:8 min_samples_per_leaf:10 num boosts:100
# Train Acc: 1.0000
# Val.  Acc: 0.9031
# Calculating: n_bc=100 max_depth:8 min_samples_per_leaf:50 num boosts:10
# Train Acc: 0.9612
# Val.  Acc: 0.9051
# Calculating: n_bc=100 max_depth:8 min_samples_per_leaf:50 num boosts:15
# Train Acc: 0.9844
# Val.  Acc: 0.9031
# Calculating: n_bc=100 max_depth:8 min_samples_per_leaf:50 num boosts:20
# Train Acc: 0.9978
# Val.  Acc: 0.9047
# Calculating: n_bc=100 max_depth:8 min_samples_per_leaf:50 num boosts:50
# Train Acc: 1.0000
# Val.  Acc: 0.9016
# Calculating: n_bc=100 max_depth:8 min_samples_per_leaf:50 num boosts:100
# Train Acc: 1.0000
# Val.  Acc: 0.9028

# %%
# print n trees vs. n_boost vs. accuracy 
plt.figure()
for l, nboost in enumerate(n_boost):
    plt.plot(n_trees, train_acc_bf[:,2,1,l], label=nboost)
    plt.plot(n_trees, test_acc_bf[:,2,1,l], label=nboost, linestyle='--')
plt.xscale('log')
plt.legend(ncol=2)
plt.show()

# %%
best_score = np.max(test_acc_bf)
best_params = np.argwhere(test_acc_bf==best_score)[0]
ntrees = n_trees[best_params[0]]
depthmax = max_depth[best_params[1]]
minperleaf = min_per_leaf[best_params[2]]
nboost = n_boost[best_params[3]]

# %%
#load up from the scan
best_score = 90.93
ntrees=50
depthmax=6
minperleaf=1
nboost=20

# %%
print(f'Best Test Score:{best_score} n_trees={ntrees} depthmax={depthmax} minperleaf={minperleaf} nboost={nboost}')
clf=RandomForestClassifier(n_estimators=ntrees, 
    max_depth=depthmax, 
    bootstrap=True, min_samples_leaf=minperleaf,
)
bf = AdaBoostClassifier(base_estimator=clf, n_estimators=nboost, random_state=43)
bf.fit(new_train,yy_train)
# Out:
# Best Test Score:90.93 n_trees=50 depthmax=6 minperleaf=1 nboost=20
# AdaBoostClassifier(base_estimator=RandomForestClassifier(max_depth=6,
#                                                          n_estimators=50),
#                    n_estimators=20, random_state=43)

# %%
print(bf.score(new_train, y_train))
print(bf.score(new_test, y_test))
# Out:
# 0.9954786203332903
# 0.9093374660984115

# %%
bf_scores = bf.predict_proba(new_test)

# %%
bf_prob = np.asarray(bf_scores[:,1])

# %%
x = new_test['beta_one']
y = new_test['azimuth_ks']
plt.figure()
plt.subplot(111)
plot_step=50
x_min, x_max = x.min() - 1, x.max() + 1
y_min, y_max = y.min() - 1, y.max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, plot_step),
                     np.arange(y_min, y_max, plot_step))

Z = bf.predict(new_test)
# Z = Z.reshape(xx.shape)
# cs = plt.contourf(x, y, Z, cmap=plt.cm.Paired)
plt.scatter(x, y, c=Z, cmap=plt.cm.plasma, vmin=-0.3, vmax=1.3, s=5)
# plt.contour()
plt.axis("tight")

plt.xlim(-0.1, 0.3)
plt.ylim(0, .6)
plt.show()

# %%
kw = dict(histtype='step', bins=50, range=[0,1])
plt.hist(bf_prob[val.y==0], **kw, label='first event from fast-n')
plt.hist(bf_prob[val.y==1], **kw, label='IBD positron')

plt.xlabel('Boosted Model Output Probability', fontsize=14)
plt.ylabel('Counts', fontsize=12)
plt.legend()
plt.yscale('log')
plt.show()

# %%
precision_recall_fscore_support(y_test, np.round(bf_scores[:,1]))
# Out:
# (array([0.93198381, 0.88855869]),
#  array([0.88470407, 0.934375  ]),
#  array([0.90772871, 0.91089109]),
#  array([1301, 1280]))

# %%
ml = ML_Evaluation(y_test, bf_scores)
ml.draw_confmat(extra_title='\nH$_2$O: Boosted Forest')
bf_tpr, bf_fpr, bf_thresholds = ml.draw_roc(extra_title='\nH$_2$O: Boosted Forest')
results['bf'] = dict(scores=bf_scores, tpr=bf_tpr, fpr=bf_fpr, thresholds=bf_thresholds)
bf_acceptances = dict(fpr=bf_fpr, tpr=bf_tpr)
# save_obj(acceptances, 'rates')
quick_analysis(bf_acceptances, medium='h2o')

# %%
bf_feature_imp = pd.Series(bf.feature_importances_,index=dims_add).sort_values(ascending=False)

# %%
# Creating a bar plot
plt.figure(figsize=(4, 6))
ax = sns.barplot(x=bf_feature_imp, 
                 y=bf_feature_imp.index, order=rf_feature_imp.index,
                 palette = colors, 
                )

ax.yaxis.set_ticklabels(rf_feature_imp.index,)
# for ticklabel, tickcolor in zip(plt.gca().get_yticklabels(), colors):
#     ticklabel.set_color(tickcolor)

# ax.yaxis.set_tick_params(color=colors)
# Add labels to your graph
plt.xlabel('Feature Importance Score')
plt.xscale('log')
plt.xlim(1e-3, .2)
# plt.ylabel('Features')
plt.title("Feature Importance: Boosting \nFast-neutron/IBD in H$_2$O")
plt.show()

# %%
plt.plot(np.logspace(-3,-0.5,50), np.logspace(-3,-0.5,50), 
         c='k', lw=1, ls='--', label='equal weight')
for i, rf_ftr  in enumerate(rf_feature_imp):
    plt.scatter(rf_feature_imp[i], bf_feature_imp[rf_feature_imp.index[i]], 
                c= colors[i], 
               )
plt.ylim(5e-3, 2e-1)
plt.xlim(5e-3, 2e-1)

plt.xlabel("Random forest decision importance", fontsize=13)
plt.ylabel("Boosting importance", fontsize=13)
plt.xscale('log')
plt.yscale('log')
plt.legend(loc='upper left', ncol=2)
plt.show()

# %%
methods = ['rf', 'bf', 'gcn']

# %%
lines=4
evenly_spaced_interval = np.linspace(0, .9, lines)
colors = [plt.cm.plasma(x) for x in evenly_spaced_interval]
colors2 = [plt.cm.winter(x) for x in evenly_spaced_interval]

methodlabels = ['baseline', 'RF', 'boosting', 'GCN']
legendkeys = [1, 5, 2, 6, 3, 7, 0, 4]

# %%
ncore=2
plot_times_overlay(results, 'h2o', all_rates, ncore=ncore, 
                   which_times='anom',
                   extra_title='H$_2$O: %i-Core Signal'%(ncore))

# %%
lines=4
evenly_spaced_interval = np.linspace(0, .9, lines)
colors = [plt.cm.plasma(x) for x in evenly_spaced_interval]
colors2 = [plt.cm.winter(x) for x in evenly_spaced_interval]

methodlabels = dict(baseline='baseline', rf='RF', bf='boosting', gcn='GCN')
legendkeys =[0,1,2,3,4,5,6,7]#  [1, 5, 2, 6, 3, 7, 0, 4]

# %%
def plot_times_overlay(results, 
               medium, 
               all_rates, 
               ncore=1,
               extra_title='', 
               which_times='both'       
                      ):

    s0, b0 = get_s_and_b(**all_rates[medium], ncore=ncore)
    t_anom0, t_meas0 = get_times(s0, b0)
    
    fig, ax = plt.subplots(1,1, figsize=(7, 5), )
    plt.suptitle("Dwell Times to Anomaly Detection and Measurement \n %s"%(extra_title))
    ax.hlines(t_anom0, 0, 1, 
           color=colors[0], linestyle='--', lw=2, 
           label='t$_{anom}$, %s (%.1f d)'%(methodlabels['baseline'], t_anom0)
          )

    
    for m, method in enumerate(['rf','bf','gcn']):
        methodlabel=methodlabels[method]
        acceptances = results[method]
        ml_rates = ml_roc_rates(acceptances, medium, all_rates)
        s, b = get_s_and_b(**ml_rates, ncore=ncore)
        t_anom, t_meas = get_times(s, b)
    
        tpr = acceptances['tpr']
        fpr = acceptances['fpr']
        #get rid of 0-multiplication mishaps 
        mask = fpr > 0. 
        fpr, tpr = fpr[mask], tpr[mask]

        ax.plot(fpr, t_anom, 
             color=colors[m+1], lw=2, 
             label='t$_{anom}$, %s (%.1f d)'%( methodlabel, np.min(t_anom))
            )
#     if which_times=='both' or 'meas':
#         ax.plot(fpr, t_meas, 
#              color=colors2[m+1], lw=2, 
#              label='t$_{meas}$, %s (%.1f d)'%( methodlabel, np.min(t_meas))
#             )
#         ax.hlines(t_meas0, 0, 1, 
#                color=colors2[0], linestyle='--', lw=2, 
#                label='t$_{meas}$, %s (%.1f d)'%(methodlabels[0], t_meas0)
#               )
    handles, labels = ax.get_legend_handles_labels()
    # sort both labels and handles by labels
    labels, handles, methods = zip(*sorted(zip(labels, handles, legendkeys), key=lambda t: t[0]))
    leg1 = ax.legend(handles[:4], labels[:4], bbox_to_anchor=(1., 0.3))
#     leg2 = ax.legend(handles[4:], labels[4:], bbox_to_anchor=(1., 0.8))
# pyplot.legend([l[0] for l in plot_lines], parameters, loc=4)
    plt.gca().add_artist(leg1)
#     plt.gca().add_artist(leg2)
    ax.set_xlabel('Fast-neutron Acceptance (Rel. to Cuts)', fontsize=12)
    ax.set_ylabel('Dwell time (days)', fontsize=12)    
    ax.grid()
    ax.set_xlim(0.0, 1.0)
    ax.set_ylim(min([t_anom0, min(t_anom), t_meas0, min(t_meas)])*.6,
             max([t_anom0, t_meas0])*1.2)
    plt.show()

# %%
def plot_times_overlay(results, 
               medium, 
               all_rates, 
               ncore=1,
               extra_title=''):

    s0, b0 = get_s_and_b(**all_rates[medium], ncore=ncore)
    t_anom0, t_meas0 = get_times(s0, b0)
    
    fig, ax = plt.subplots(1,1, figsize=(7, 5), )
    plt.suptitle("Dwell Times to Anomaly Detection and Measurement \n %s"%(extra_title))
    ax.hlines(t_anom0, 0, 1, 
           color=colors[0], linestyle='--', lw=2, 
           label='t$_{anom}$, %s (%.1f d)'%(methodlabels[0], t_anom0)
          )
    ax.hlines(t_meas0, 0, 1, 
           color=colors2[0], linestyle='--', lw=2, 
           label='t$_{meas}$, %s (%.1f d)'%(methodlabels[0], t_meas0)
          )
    
    for m, method in enumerate(results.keys()):
        methodlabel=methodlabels[m+1]
        acceptances = results[method]
        ml_rates = ml_roc_rates(acceptances, medium, all_rates)
        s, b = get_s_and_b(**ml_rates, ncore=ncore)
        t_anom, t_meas = get_times(s, b)
    
        tpr = acceptances['tpr']
        fpr = acceptances['fpr']
        #get rid of 0-multiplication mishaps 
        mask = fpr > 0. 
        fpr, tpr = fpr[mask], tpr[mask]

        ax.plot(fpr, t_anom, 
             color=colors[m+1], lw=2, 
             label='t$_{anom}$, %s (%.1f d)'%( methodlabel, np.min(t_anom))
            )

        ax.plot(fpr, t_meas, 
             color=colors2[m+1], lw=2, 
             label='t$_{meas}$, %s (%.1f d)'%( methodlabel, np.min(t_meas))
            )
    
    handles, labels = ax.get_legend_handles_labels()
    # sort both labels and handles by labels
    labels, handles, methods = zip(*sorted(zip(labels, handles, legendkeys), key=lambda t: t[2]))
    leg1 = ax.legend(handles[:4], labels[:4], bbox_to_anchor=(1., 0.3))
    leg2 = ax.legend(handles[4:], labels[4:], bbox_to_anchor=(1., 0.8))
# pyplot.legend([l[0] for l in plot_lines], parameters, loc=4)
    plt.gca().add_artist(leg1)
    plt.gca().add_artist(leg2)
    ax.set_xlabel('Fast-neutron Acceptance (Rel. to Cuts)', fontsize=12)
    ax.set_ylabel('Dwell time (days)', fontsize=12)    
    ax.grid()
    ax.set_xlim(0.0, 1.0)
    ax.set_ylim(min([t_anom0, min(t_anom), t_meas0, min(t_meas)])*.6,
             max([t_anom0, t_meas0])*1.2)
    plt.show()

# %% [markdown]
# ------
