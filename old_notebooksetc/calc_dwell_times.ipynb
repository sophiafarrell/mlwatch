# %%
from calc_dwelltimes import *

# %%
core_rates = load_obj('core_rates', directory='./data/')
acceptances = load_obj('rates')

# %%
quick_analysis(acceptances)
